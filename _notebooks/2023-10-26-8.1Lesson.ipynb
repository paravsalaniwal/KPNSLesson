# %% [markdown]
# ---
# layout: post
# title: Unit 8 Lesson - 2D Arrays
# description: Group Lesson on Unit 8 which covers 2D arrays
# toc: true
# permalink: /unit8lesson
# ---

# %% [markdown]
# # 8.1

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## Learning Objective
# Represent collections of related primitive or object reference data using two-dimensional array objects.
#
# ## Essential Knowledge
#
# 2D arrays are stored as array of arrays.
#
# The initializer array used to create and initiate a 2D array consists of initializer lists that represent 1D arrays.

# %% [markdown]
# ## What is a 2D array
#
# A 2D array is an array of arrays.
#
# ![image.png](attachment:image.png)
#
# ## Why use 2D arrays?
#
# 1D array of people
# ```
# {
# "Patrick Mahomes"
# "Mr. Mortensen"
# "Taylor Swift"
# "Margot Robbie"
# }
# ```
#
# 2D array of men and women
# ```
# {
# { "Patrick Mahomes", "Mr. Mortensen"} ,
# {"Taylor Swift", "Margot Robbie"}
# }
# ```
